# %% [markdown]
# <a href="https://colab.research.google.com/github/Akanksha-Ceris/100-days-of-machine-learning/blob/main/Day11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# function returning a value part 2
def print_name(firstname):
  return firstname
print_name('Akanksha')
def print_full_name(firstname,lastname):
  space = ' '
  full_name = firstname + space + lastname
  return full_name
print_full_name(firstname= 'Akanksha',lastname = "kumari")
# Out:
# 'Akanksha kumari'

# %%
def add_two_number(num1,num2):
  total = num1 + num2
  return total
print(add_two_number(2,3))
def calculate_age(current_year,birth_year)
    age = current_year - birth_year
    return age
print("Age:",calculate_age(2020-34))
# Out:
#   File "/tmp/ipykernel_4437/554331255.py", line 5
#     def calculate_age(current_year,birth_year)
#                                               ^
# SyntaxError: expected ':'

# %%
def greetings(name = "Peter"):
    message = name +', welcome to python for everyone!'
    return message
print(greetings())
print(greetings('Akanksha'))
# Out:
# Peter, welcome to python for everyone!
# Akanksha, welcome to python for everyone!

# %%
def generate_full_name(first_name = 'Akanksha',last_name = 'kumari'):
  space = ' '
  full_name = first_name + last_name
  return full_name
print(generate_full_name())
# Out:
# Akankshakumari

# %%
def weight_of_object(mass,gravity = 9.0):
  weight = str(mass * gravity) + 'N'
  return weight
print('weight of an object in Newtorn:',weight_of_object(100))
print('weight of an object in Newtons' ,weight_of_object(89))
# Out:
# weight of an object in Newtorn: 900.0N
# weight of an object in Newtons 801.0N

# %%
def function_name(*args):
  # code
  # codes
# function_name(param1,param2,para)

# %%
def generate_groups (team,*args):
  print(team)
  for i in args:
    print(i)
generate_groups("Team1:","akanksha","brook","david",'eyob')
# Out:
# Team1:
# akanksha
# brook
# david
# eyob

# %%
def sum_all_num(*nums):
  total = 0
  for num in nums:
    total += num
  return total
print(sum_all_num(2,3,5)  )
# Out:
# 10

# %%
def generate_groups(team,*args):
  print(team)
  for i in args:
    print(i)
generate_groups('Team1',"akanksha")
# Out:
# Team1
# akanksha

# %%
def greet(name,location):
  print("hi there",name, "how is the whether in",location)
greet(name = "Alice",location= "newyork")
# Out:
# hi there Alice how is the whether in newyork

# %%
my_dict = {"name": "Alice","location":"newyork"}
greet(**my_dict)
# Out:
# hi there Alice how is the whether in newyork
